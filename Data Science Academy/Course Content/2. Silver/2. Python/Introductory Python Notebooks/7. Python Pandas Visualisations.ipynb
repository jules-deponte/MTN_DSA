# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts
# Out:
# 2000-01-01     0.566396
# 2000-01-02    -0.370576
# 2000-01-03    -0.917992
# 2000-01-04     0.261214
# 2000-01-05    -0.975791
#                 ...
# 2002-09-22    27.762367
# 2002-09-23    27.654775
# 2002-09-24    27.499304
# 2002-09-25    28.267297
# 2002-09-26    30.050468
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
plt.figure()
df.plot();

# %%
plt.figure();

df.iloc[5].plot(kind='bar');

# %%
plt.figure();

df.iloc[5].plot.bar()


plt.axhline(0, color='k');
